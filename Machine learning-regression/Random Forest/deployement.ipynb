# %%
import pickle

# %%
loaded_model=pickle.load(open("final_model_Random_forest_regressor.sav",'rb'))
result=loaded_model.predict([[165349,136897,471784,0,1]])
# Out:
# C:\ANACONDA\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([187609.33])
