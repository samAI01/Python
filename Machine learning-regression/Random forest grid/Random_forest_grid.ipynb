# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True).astype(int)

# %%
dataset
# Out:
#       age  bmi  children  charges  sex_male  smoker_yes
# 0      19   27         0    16884         0           1
# 1      18   33         1     1725         1           0
# 2      28   33         3     4449         1           0
# 3      33   22         0    21984         1           0
# 4      32   28         0     3866         1           0
# ...   ...  ...       ...      ...       ...         ...
# 1333   50   30         3    10600         1           0
# 1334   18   31         0     2205         0           0
# 1335   18   36         0     1629         0           0
# 1336   21   25         0     2007         0           0
# 1337   61   29         0    29141         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
independent
# Out:
#       age  bmi  children  sex_male  smoker_yes
# 0      19   27         0         0           1
# 1      18   33         1         1           0
# 2      28   33         3         1           0
# 3      33   22         0         1           0
# 4      32   28         0         1           0
# ...   ...  ...       ...       ...         ...
# 1333   50   30         3         1           0
# 1334   18   31         0         0           0
# 1335   18   36         0         0           0
# 1336   21   25         0         0           0
# 1337   61   29         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[['charges']]

# %%
dependent
# Out:
#       charges
# 0       16884
# 1        1725
# 2        4449
# 3       21984
# 4        3866
# ...       ...
# 1333    10600
# 1334     2205
# 1335     1629
# 1336     2007
# 1337    29141
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.20,random_state=0)

# %%
x_train
# Out:
#       age  bmi  children  sex_male  smoker_yes
# 621    37   34         4         1           1
# 194    18   34         0         1           0
# 240    23   36         2         0           1
# 1168   32   35         2         1           0
# 1192   58   32         1         0           0
# ...   ...  ...       ...       ...         ...
# 763    27   26         0         1           0
# 835    42   35         2         1           0
# 1216   40   25         0         1           0
# 559    19   35         0         1           0
# 684    33   18         1         0           0
#
# [1070 rows x 5 columns]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid = {'criterion':['poisson','squared_error'],'max_features': ['auto','sqrt'],'n_estimators':[10,100]}
grid=GridSearchCV(RandomForestRegressor(random_state=0),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# C:\ANACONDA\Lib\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 20 fits failed out of a total of 40.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\ANACONDA\Lib\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\ANACONDA\Lib\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "C:\ANACONDA\Lib\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self._parameter_constraints,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         self.get_params(deep=False),
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         caller_name=self.__class__.__name__,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\ANACONDA\Lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
#     ...<2 lines>...
#     )
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\ANACONDA\Lib\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\ANACONDA\Lib\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "C:\ANACONDA\Lib\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self._parameter_constraints,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         self.get_params(deep=False),
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         caller_name=self.__class__.__name__,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\ANACONDA\Lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
#     ...<2 lines>...
#     )
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\ANACONDA\Lib\site-packages\sklearn\model_selection\_search.py:1108: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.7981161  0.81327815        nan        nan
#  0.7917589  0.81079791]
#   warnings.warn(
# C:\ANACONDA\Lib\site-packages\sklearn\base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(random_state=0), n_jobs=-1,
#              param_grid={'criterion': ['poisson', 'squared_error'],
#                          'max_features': ['auto', 'sqrt'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
re=grid.cv_results_

# %%
re
# Out:
# {'mean_fit_time': array([0.00249805, 0.0032197 , 0.06230087, 0.34374704, 0.00255203,
#         0.00184379, 0.04093285, 0.30334725]),
#  'std_fit_time': array([0.00060498, 0.00063352, 0.02189014, 0.01286459, 0.00109595,
#         0.00041096, 0.00173754, 0.00287711]),
#  'mean_score_time': array([0.        , 0.        , 0.00873132, 0.02244697, 0.        ,
#         0.        , 0.008534  , 0.02003689]),
#  'std_score_time': array([0.        , 0.        , 0.00127869, 0.00152249, 0.        ,
#         0.        , 0.00184194, 0.00278224]),
#  'param_criterion': masked_array(data=['poisson', 'poisson', 'poisson', 'poisson',
#                     'squared_error', 'squared_error', 'squared_error',
#                     'squared_error'],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value=np.str_('?'),
#              dtype=object),
#  'param_max_features': masked_array(data=['auto', 'auto', 'sqrt', 'sqrt', 'auto', 'auto', 'sqrt',
#                     'sqrt'],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value=np.str_('?'),
#              dtype=object),
#  'param_n_estimators': masked_array(data=[10, 100, 10, 100, 10, 100, 10, 100],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value=999999),
#  'params': [{'criterion': 'poisson',
#    'max_features': 'auto',
#    'n_estimators': 10},
#   {'criterion': 'poisson', 'max_features': 'auto', 'n_estimators': 100},
#   {'criterion': 'poisson', 'max_features': 'sqrt', 'n_estimators': 10},
#   {'criterion': 'poisson', 'max_features': 'sqrt', 'n_estimators': 100},
#   {'criterion': 'squared_error', 'max_features': 'auto', 'n_estimators': 10},
#   {'criterion': 'squared_error', 'max_features': 'auto', 'n_estimators': 100},
#   {'criterion': 'squared_error', 'max_features': 'sqrt', 'n_estimators': 10},
#   {'criterion': 'squared_error', 'max_features': 'sqrt', 'n_estimators': 100}],
#  'split0_test_score': array([       nan,        nan, 0.83173216, 0.8505071 ,        nan,
#                nan, 0.83031229, 0.8442553 ]),
#  'split1_test_score': array([       nan,        nan, 0.81532552, 0.82229676,        nan,
#                nan, 0.81873585, 0.82934166]),
#  'split2_test_score': array([       nan,        nan, 0.78106922, 0.79926267,        nan,
#                nan, 0.75974462, 0.79435656]),
#  'split3_test_score': array([       nan,        nan, 0.80656653, 0.8238599 ,        nan,
#                nan, 0.79415859, 0.81763018]),
#  'split4_test_score': array([       nan,        nan, 0.75588705, 0.77046431,        nan,
#                nan, 0.75584317, 0.76840585]),
#  'mean_test_score': array([       nan,        nan, 0.7981161 , 0.81327815,        nan,
#                nan, 0.7917589 , 0.81079791]),
#  'std_test_score': array([       nan,        nan, 0.0267264 , 0.02686545,        nan,
#                nan, 0.03011555, 0.02674828]),
#  'rank_test_score': array([5, 5, 3, 1, 5, 5, 4, 2], dtype=int32)}

# %%
format(grid.best_params_)
# Out:
# "{'criterion': 'poisson', 'max_features': 'sqrt', 'n_estimators': 100}"

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.002498      0.000605         0.000000        0.000000
# 1       0.003220      0.000634         0.000000        0.000000
# 2       0.062301      0.021890         0.008731        0.001279
# 3       0.343747      0.012865         0.022447        0.001522
# 4       0.002552      0.001096         0.000000        0.000000
# 5       0.001844      0.000411         0.000000        0.000000
# 6       0.040933      0.001738         0.008534        0.001842
# 7       0.303347      0.002877         0.020037        0.002782
#
#   param_criterion param_max_features  param_n_estimators  \
# 0         poisson               auto                  10
# 1         poisson               auto                 100
# 2         poisson               sqrt                  10
# 3         poisson               sqrt                 100
# 4   squared_error               auto                  10
# 5   squared_error               auto                 100
# 6   squared_error               sqrt                  10
# 7   squared_error               sqrt                 100
#
#                                               params  split0_test_score  \
# 0  {'criterion': 'poisson', 'max_features': 'auto...                NaN
# 1  {'criterion': 'poisson', 'max_features': 'auto...                NaN
# 2  {'criterion': 'poisson', 'max_features': 'sqrt...           0.831732
# 3  {'criterion': 'poisson', 'max_features': 'sqrt...           0.850507
# 4  {'criterion': 'squared_error', 'max_features':...                NaN
# 5  {'criterion': 'squared_error', 'max_features':...                NaN
# 6  {'criterion': 'squared_error', 'max_features':...           0.830312
# 7  {'criterion': 'squared_error', 'max_features':...           0.844255
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0                NaN                NaN                NaN                NaN
# 1                NaN                NaN                NaN                NaN
# 2           0.815326           0.781069           0.806567           0.755887
# 3           0.822297           0.799263           0.823860           0.770464
# 4                NaN                NaN                NaN                NaN
# 5                NaN                NaN                NaN                NaN
# 6           0.818736           0.759745           0.794159           0.755843
# 7           0.829342           0.794357           0.817630           0.768406
#
#    mean_test_score  std_test_score  rank_test_score
# 0              NaN             NaN                5
# 1              NaN             NaN                5
# 2         0.798116        0.026726                3
# 3         0.813278        0.026865                1
# 4              NaN             NaN                5
# 5              NaN             NaN                5
# 6         0.791759        0.030116                4
# 7         0.810798        0.026748                2

# %%
age=(float(input("age:")))
bmi=float(input("bmi:"))
children=int(input("children:"))
sex_male=int(input("sex_male: Enter 0 or 1 :"))
smoker_yes=int(input("smoker: Enter 0 or 1 : "))
# Out:
# age: 12
# bmi: 12
# children: 1
# sex_male: Enter 0 or 1 : 0
# smoker: Enter 0 or 1 :  1

# %%
Future_Predictions=grid.predict([[age, bmi, children, sex_male, smoker_yes]])
format(Future_Predictions)
# Out:
# C:\ANACONDA\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# '[14590.28]'
