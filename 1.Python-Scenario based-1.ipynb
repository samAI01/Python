# %%
# 1 A system checks if a user is eligible to vote based on their age.
# 1.Write logic to ask the user for their age and determine if they are eligible to vote based on whether they are 18 or older.

# %%
class voter():
    def vote():
        age=int(input("Enter your age"))
        if(age>=18):
            print("Eligible to vote")
        else:
            print("Not Eligible for vote")
        while(age==0):
            print("invalid",False)
        return age

# %%
voter.vote()
# Out:
# Enter your age 12
# Not Eligible for vote
# 12

# %%
# 2. A company provides employees with a 10% bonus if their salary exceeds $50,000.
# Write logic to determine the bonus amount based on the given salary.

# %%
class company():
    def employee_salary():
        salary=float(input("Enter your salary amount:"))
        if(salary>=50000):
             print("Bonous:",salary*10/100) 
             print("you are eligible for 10% bonous")
        else:
             print("you are not eligible for bonus")
             return salary

# %%
##### company.employee_salary()

# %%
# 3. A program processes a list of numbers and needs to find the largest value.
# Write logic to identify and return the largest number from a given list.

# %%
list=[10,90,20,100,40,50,]
largest=list[3]
smallest=list[0]
for value in list:
        if(value>=largest):
            print(value,"largest number from a given list:")
        elif(value==smallest):
            print(value,"smallest number from a given list:")
# Out:
# 10 smallest number from a given list:
# 100 largest number from a given list:

# %%
# 4.A program evaluates a number to determine if it is even or odd.
#Write logic to check whether a given number is even or odd.

# %%
class ODDEVEN():
    def OddEven():
        number=int(input("Enter the number"))
        if(number%2==1):
             print("The number is odd")
        else:
             print("The numder is even")

# %%
ODDEVEN.OddEven()
# Out:
# Enter the number 12
# The numder is even

# %%
# 5. A text-processing tool reverses a given word or sentence for formatting purposes.
 #Write logic to take a word or sentence as input and produce its reversed version.

# %%
word=input("Enter the word or sentence")
reversed=word[::-1]
print(reversed)
# Out:
# Enter the word or sentence samuel
# leumas

# %%
# 6. A grading system determines whether a student has passed or failed based on their score.
# Write logic to check if a student has passed a subject by scoring at least 40 marks.

# %%
class result():
    def student_result():
        subject1=int(input("enter the mark1"))
        subject2=int(input("enter the mark2"))
        subject3=int(input("enter the mark3"))
        subject4=int(input("enter the mark4"))   
        subject5=int(input("enter the mark5"))            
        mark=[subject1,subject2,subject3,subject4,subject5]
        for (Mark) in mark:
            if(Mark>=40):
                print("pass")
            else:
                print("fail")

# %%
result.student_result()
# Out:
# enter the mark1 20
# enter the mark2 20
# enter the mark3 20
# enter the mark4 30
# enter the mark5 40
# fail
# fail
# fail
# fail
# pass

# %%
# 7. A retail store offers a 20% discount if a customer’s total order exceeds $100.
# Write logic to calculate the final amount to be paid after applying the discount.

# %%
class retailstore():
    def retail():
        order1=int(input("Enter the order amount"))
        order2=int(input("Enter the order amount"))
        order3=int(input("Enter the order amount"))
        order4=int(input("Enter the order amount"))
        order5=int(input("Enter the order amount"))
        total=[order1+order2+order3+order4+order5]
        print("Total order amount",total)
        for(Total_order) in total:
                if(Total_order>=100):
                       print("20% discount")
                       print("Final amount:",Total_order*20/100)
                elif(Total_order<100):
                       print("no discount")
                       print("Final amount:",Total_order)

# %%
retailstore.retail()
# Out:
# Enter the order amount 100
# Enter the order amount 100
# Enter the order amount 100
# Enter the order amount 100
# Enter the order amount 100
# Total order amount [500]
# 20% discount
# Final amount: 100.0

# %%
# 8. A banking system processes withdrawal requests and ensures the user has enough balance.
# Write logic to check if a user has enough balance before allowing a withdrawal and update the remaining balance accordingly.

# %%
class bank():
    def check():
        total=50000
        print("Enter 1 to check total amount")
        value=int(input("Enter:"))
        if(value==1):
              print("Total amount:",total)
              print(bank.withdraw())
        else:
              print("Incorrect,enter 1")
        return
        
    def withdraw():
        total=50000
        print("Enter wihdrawal amount")
        withdraw=int(input("Enter withdraw amount:"))
        if(withdraw<=total):
               print("Current balance",total-withdraw)
        elif(withdraw>=total):
               print("Insufficient balance,please check total amount")
        return

# %%
bank.check()
# Out:
# Enter 1 to check total amount
# Enter: 1
# Total amount: 50000
# Enter wihdrawal amount
# Enter withdraw amount: 4500
# Current balance 45500
# None

# %%
# 9. A calendar system verifies whether a given year is a leap year based on standard leap year rules.
 # Write logic to determine whether a given year is a leap year.

# %%
class calendar():
    def leapyear():
        year=int(input("Enter the year to find leap year or not : "))
        if(year%4==0 and year%100!=0 or year%400==0):
            print(year,"Its a leap year ")
        else:
            print(year,"Its a not leap year ")
            return year

# %%
calendar.leapyear()
# Out:
# Enter the year to find leap year or not :  2016
# 2016 Its a leap year

# %%
# 10. A program filters out only even numbers from a given list.
# Write logic to extract and return only the even numbers from a list.

# %%
list=[10 , 15 , 14 , 89 , 55, 88 , 100]
for temp in list:
    if(temp%2==0):
        print(temp, ": is Even")
# Out:
# 10 : is Even
# 14 : is Even
# 88 : is Even
# 100 : is Even
