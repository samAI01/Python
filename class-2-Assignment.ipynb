# %%
from MULTIPLEFUNCTION import multifunctions

# %%
multifunctions.sub_fields()
# Out:
# Machine Learning
# Neural Network
# Vission
# Robotics
# Speech processing
# Natural Learning

# %%
multifunctions.OddEven()
# Out:
# Enter the number: 12
# 12 Number is even

# %%
multifunctions.MarraigeEligible()
# Out:
# Enter your gender male
# <class 'str'>
# Enter your age 20
# <class 'int'>
# Eligible for a marriage
# 'Eligible for a marriage'

# %%
multifunctions.Percentage()
# Out:
# Enter the mark1 99
# Enter the mark2 98
# Enter the mark3 97
# Enter the mark4 98
# Enter the mark5 100
# Total: 492
# PERCENTAGE: 98.4
# 98.4

# %%
multifunctions.Triangle()
# Out:
# Enter the height of triangle: 12
# Enter the breadth of triangle: 3.3
# Area of triangle is: 19.799999999999997
# 19.799999999999997

# %%
multifunctions.Perimeter()
# Out:
# Enter the height of triangle: 12
# Enter the height of triangle: 4.4
# Enter the breadth of triangle: 9.3
# Area of triangle is: 25.7
# 25.7
